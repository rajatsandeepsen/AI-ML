# %% [markdown]
# # 01 - Data Understanding
#
# Goal: Load dataset, inspect shape, columns, types, and summary statistics.

# %%
import pandas as pd

# %%
df = pd.read_csv('src/module-3/datasets/student_lifestyle.csv')
df.head()

# %%
print('Shape:', df.shape)
print('Columns:', list(df.columns))
# Out:
# Shape: (12, 9)
# Columns: ['student_id', 'age', 'gender', 'study_hours', 'sleep_hours', 'daily_screen_time', 'attendance_percent', 'exam_score',
# 'city']

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   student_id          12 non-null     str
#  1   age                 12 non-null     int64
#  2   gender              12 non-null     str
#  3   study_hours         11 non-null     float64
#  4   sleep_hours         11 non-null     float64
#  5   daily_screen_time   11 non-null     float64
#  6   attendance_percent  11 non-null     float64
#  7   exam_score          11 non-null     float64
#  8   city                12 non-null     str
# dtypes: float64(5), int64(1), str(3)
# memory usage: 996.0 bytes

# %%
df.describe(numeric_only=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df.describe(numeric_only=True)
# TypeError: NDFrame.describe() got an unexpected keyword argument 'numeric_only'
